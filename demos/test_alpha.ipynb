# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

#%matplotlib widget

# %%
path = r"/Users/emmawindges/PEP-ODE-2/build"

# %%
import matplotlib.pyplot as plt

alpha = pd.read_csv(f"{path}/alpha.csv")

plt.figure()
plt.xlabel('')
plt.ylabel('')
#plt.plot(alpha["t"], label="time")
plt.plot(alpha["t"], alpha["x[0]"], label="x[0]")
plt.plot(alpha["t"], alpha["x[1]"], label="x[1]")
plt.plot(alpha["t"], alpha["x[2]"], label="x[2]")

plt.title('')

plt.legend()
plt.grid(True)
plt.show()
